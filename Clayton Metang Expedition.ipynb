# %% [markdown]
# # Clayton Metang — Expedition
# High-level workflow using `expedition.py`. Each cell calls one stage; `x.save()` persists config after each step.

# %%
import logging
import claytonlib as clayton
from claytonlib.expedition import expedition

# --- Logging ---
# INFO shows per-write-cycle timing; DEBUG adds per-turn RNG details
logging.basicConfig(level=logging.WARNING)
# logging.getLogger('claytonlib').setLevel(logging.INFO)

x = expedition("metang")
x.reload()
x.print()
# Out:
# [expedition] Reloaded from data/expeditions/metang.json
# === Expedition: metang ===
#   pokemon           metang
#   key_seed          0xEC1504DC
#   setup_delay_s     300
#   max_target_s      900
#   strategy          six-bait-then-balls
#   criteria          machete-50-turns-after-5-balls
#   eval_strategy     sliding_window_13
#   window            (not set)
#   target_delay      (not set)
#   initial_time      (not set)
#   target_seeds      (none)
#   metronome_histsz  (not set)

# %% [markdown]
# ## Chart

# %%
x.chart_safari()
x.save()

# %% [markdown]
# ## Evaluate

# %%
x.evaluate_chart()
x.save()

# %% [markdown]
# ## Choose Target

# %%
x.choose_target()
x.save()
# Out:
# [expedition] === choose_target ===  07:55:18
# [expedition] === evaluate_chart ===  07:55:18
# [expedition] === chart_safari ===  07:55:18
# [expedition] Charting metang key_seed=0xEC1504DC delay=300-900s strategy=six-bait-then-balls criteria=machete-50-turns-after-5-balls
# [expedition] chart_safari complete.
# [expedition] Evaluating with strategy=sliding_window_13
# [expedition] evaluate_chart complete.
#
# Top 10 (t1-t10):
#        score  prob   delay  time      +key_s
#   t1   7.87   60.5%  23568  21:59:59  +372.07s
#   t2   7.77   59.8%  23566  21:59:59  +372.03s
#   t3   7.7    59.2%  23568  21:55:59  +372.07s
#   t4   7.67   59.0%  27958  22:04:59  +445.23s
#   t5   7.6    58.5%  23566  21:55:59  +372.03s
#   t6   7.57   58.2%  23566  21:56:58  +372.03s
#   t7   7.5    57.7%  23560  21:59:58  +371.93s
#   t8   7.47   57.5%  39952  22:04:59  +645.13s
#   t9   7.4    56.9%  23560  21:55:58  +371.93s
#   t10  7.4    56.9%  23568  21:56:58  +372.07s
#
# Best 10 (b1-b10):
#        score  prob   delay  time      +key_s
#   b1   7.87   60.5%  23568  21:59:59  +372.07s
#   b2   7.77   59.8%  23566  21:59:59  +372.03s
#   b3   7.5    57.7%  23560  21:59:58  +371.93s
#   b4   7.23   55.6%  23558  21:55:58  +371.90s
#   b5   6.8    52.3%  21714  21:56:58  +341.17s
#   b6   6.77   52.1%  21320  21:58:33  +334.60s
#   b7   6.63   51.0%  20430  21:57:58  +319.77s
#   b8   6.37   49.0%  20190  21:58:14  +315.77s
#   b9   6.07   46.7%  20140  22:01:44  +314.93s
#   b10  5.5    42.3%  20110  21:59:41  +314.43s
#
# Enter a label (t1-t10, b1-b10) or a hex seed to use directly.
# Choice:  b1
# [expedition] Target set: delay=23568  initial_time=2000-08-17T21:53:47
# [expedition] Delay from key seed: 22324 frames  (372.07s)
# [expedition] Saved to data/expeditions/metang.json

# %%
### Calibration step 1 - Calibrate to short delay
x.adjust(target_delay=1904)
x.print()
x.compass_metronome()
# Out:
# [expedition] target_delay = 1904
# === Expedition: metang ===
#   pokemon           metang
#   key_seed          0xEC1504DC
#   setup_delay_s     300
#   max_target_s      900
#   strategy          six-bait-then-balls
#   criteria          machete-50-turns-after-5-balls
#   eval_strategy     sliding_window_13
#   window            (not set)
#   target_delay      1904
#   initial_time      2000-08-17T21:53:47
#   target_seeds      (none)
#   metronome_histsz  (not set)
#   ---
#   delay_from_key    660 frames  (11.00s)
# [expedition] === compass_metronome ===  07:59:54
# Compass window size (frames):  180
# Compass metronome history size (0 to disable):  10
# [expedition] Delay from key seed: 660 frames  (11.00s)
# === Compass: Metronome Seed Identifier ===
# Opponent: Magikarp
# Window:   ±180 frames (355 initial candidates)
#
#
# Seeds: 355 / 355 remaining
#    #        Seed    Delay      Δ
#    1. 0xF41506BC     1724   -180
#    2. 0xF41506BE     1726   -178
#    3. 0xF51506BE     1726   -178
#    4. 0xF41506C0     1728   -176
#    5. 0xF51506C0     1728   -176
#    6. 0xF41506C2     1730   -174
#    7. 0xF51506C2     1730   -174
#    8. 0xF41506C4     1732   -172
#    9. 0xF51506C4     1732   -172
#   10. 0xF41506C6     1734   -170

# %% [markdown]
# ## Compass

# %%
x.compass_safari()
x.save()

# %% [markdown]
# ## Machete

# %%
x.machete_one()
x.save()
