# %%
## Imports
import claytonlib as clayton
KEY_SEED = 0xEC1504DC

# %%
## Configure

clayton.ChartOptions()

# %%
# Out:
# ChartConfig(evaluation_frames_per_write_cycle=60, resume_validation_enabled=False, resume_validation_frames=2, resume_strict=False)
